# %%
# DIAGRAMA DE LIENAS
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 8, 27, 64, 125]

plt.plot(x,y)
plt.show()

# %%
# DIAGRAMA DE DISPERSION O PUNTOS
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 8, 27, 64, 125]

plt.scatter(x,y)
plt.show()

# %%
# dIAGRAMA DE BARRAS VERTICALES
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 8, 27, 64, 125]

plt.bar(x,y)
plt.show()

# %%
# DIAGRAMA DE PASTEL
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 8, 27, 64, 125]

plt.pie(x)
plt.show()

# %%
# EJERCICIO DE CLASE
import pandas as pd
import matplotlib.pyplot as plt

fbk = ["Facebook", 2449, 2006]
twt = ["Twitter", 339, 2006]
ig = ["Instagram", 1000, 2009]
yt = ["YouTube", 2000, 2005]
wsp = ["Whatsapp", 1600, 2009]

lista_redes = [fbk, twt, ig, yt, wsp]

df_redes = pd.DataFrame(lista_redes, columns=["nombre", "cantidad", "año"])

plt.plot(df_redes["nombre"], df_redes["cantidad"])
plt.title("Diagrama de lineas")
plt.xlabel("Redes")
plt.ylabel("Cantidad")
plt.show()

# %%
# EJERCICIO 1
import pandas as pd
import matplotlib.pyplot as plt

fbk = ["Facebook", 2449, 2006]
twt = ["Twitter", 339, 2006]
ig = ["Instagram", 1000, 2009]
yt = ["YouTube", 2000, 2005]
wsp = ["Whatsapp", 1600, 2009]

lista_redes = [fbk, twt, ig, yt, wsp]

df_redes = pd.DataFrame(lista_redes, columns=["nombre", "cantidad", "año"])

plt.barh(df_redes["nombre"], df_redes["cantidad"])
plt.title("Diagrama de lineas")
plt.xlabel("Cantidad")
plt.ylabel("Redes")
plt.show()

# %%
# EJERCICO 2
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Año': [2010, 2011, 2012, 2013, 2014, 2015, 2016],
    'Nota Examen 1': [85, 88, 90, 92, 87, 89, 91],
    'Nota Examen 2': [78, 82, 84, 86, 80, 85, 88]
}

df = pd.DataFrame(data)

plt.fill_between(df['Año'], df['Nota Examen 1'], df['Nota Examen 2'], color='skyblue', alpha=0.5, label=['Examen 1', 'Examen 2'])

plt.xlabel('Año')
plt.ylabel('Nota del Examen')

plt.title('Evolución de las Notas de Examen 1 y Examen 2 a lo largo de los Años')

plt.legend(loc='upper left')

plt.show()
